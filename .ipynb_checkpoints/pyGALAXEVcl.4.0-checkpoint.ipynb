# %% [markdown]
# # Galaxy Spectral Evolution Library - pyGALAXEV
# ## (C) 2003-2023 - G. Bruzual and S. Charlot - All Rights Reserved
#
# Starting with the present release, each **GALAXEV** SSP model is provided as a single fits table file. Models are available for the metallicity **Z** indicated in the table. The **2019** models are based on the **PARSEC** evolutionary tracks (Chen et al. 2015; Marigo et al. 2013). In the **CB19** models (a.k.a. **C&B** models) the evolution of Post AGB stars follows Miller Bertolami (2018) whereas in the **BC19** models the Post AGB stars are treated as in Bruzual & Charlot (2003) following Vassiliadis & Wood (1994). The **BC03** models follow the **Padova 1994** evolutionary tracks and the **CB03** models the **Padova 2000** tracks (see Bruzual & Charlot 2003 for details). The **CB07** models are identical to the **BC03** models except for an enhanced contribution from TP-AGB stars (Bruzual 2007a,b).
# <table>
# <tr>
#   <th>Model Release
#   <th>2019
#   <th>BC19/CB19
#   <td>
#   <th>Z:
#   <td>0
#   <td>
#   <td>0.0001
#   <td>
#   <td>0.0002
#   <td>
#   <td>0.0005
#   <th>
#   <td>0.001
#   <td>
#   <td>0.002
#   <td>
#   <td>0.004
#   <td>
#   <td>0.006
#   <td>
#   <td>0.008
#   <td>
#   <td>0.010
#   <td>
#   <td>0.014
#   <td>
#   <td>0.017
#   <th>
#   <td>0.02
#   <td>
#   <td>0.03
#   <td>
#   <td>0.04
#   <td>
#   <td>0.06
# </tr>
# <tr>
#   <th>Model Release
#   <th>2003
#   <th>BC03/CB03/CB07
#   <td>
#   <th>Z:
#   <td>
#   <td>
#   <td>0.0001
#   <td>
#   <td>
#   <td>
#   <td>0.0004
#   <th>
#   <td>0.001
#   <td>
#   <td>
#   <td>
#   <td>0.004
#   <td>
#   <td>
#   <td>
#   <td>0.008
#   <td>
#   <td>
#   <td>
#   <td>
#   <td>
#   <td>
#   <th>
#   <td>0.02
#   <td>
#   <td>0.03
#   <td>
#   <td>0.05
#   <td>
#   <td>
# </tr>
# </table>
# Models have been computed for the combination of parameters listed in the table. The <b>Stellar Library</b> entry refers to the stellar atlas used in the visible range, except for the BaSeL models which extend from the UV to the IR. To explore the <b>GALAXEV</b> models, several tasks are provided in the <b>pyGALAXEV</b> cell bellow. Default or recommended values are indicated in <span style="color:blue">blue</span>.
# <table>
# <tr>
#   <th>Model
#   <td>
#   <th>IMF
#   <td>
#   <th>Mup
#   <td>
#   <td>
#   <td>
#   <td>
#   <td>
#   <td>
#   <td>
#   <th>Model
#   <td>
#   <th>IMF
#   <td>
#   <th>Mup
#   <td>
#   <td>
#   <td>
#   <td>
#   <td>
#   <th>Stellar Libraries (all models)
# <tr>
#   <th><span style="color:blue">CB19</span>
#   <td>
#   <td>Chabrier, Kroupa, Salpeter
#   <td>
#   <td><span style="color:blue">100</span>, 10, 300, 600 Mo
#   <td>
#   <td>
#   <td>
#   <td>
#   <td>
#   <td>
#   <td>
#   <th>BC19
#   <td>
#   <td>Chabrier
#   <td>
#   <td><span style="color:blue">100</span> Mo
#   <td>
#   <td>
#   <td>
#   <td>
#   <td>
#   <td><span style="color:blue">Miles</span>, Miles+, IndoUS, Stelib, BaSel
# <tr>
#   <th>
#   <td>
#   <td>Vazdekis et al. (1996)
#   <td>
#   <td><span style="color:blue">100</span> Mo
#   <td>
#   <td>
#   <td>
#   <td>
#   <td>
#   <td>
#   <td>
#   <th>BC03/CB03/CB07
#   <td>
#   <td>Chabrier, Kroupa, Salpeter
#   <td>
#   <td><span style="color:blue">100</span> Mo
#   <td>
#   <td>
# <tr>
# </table>

# %%
from pyGALAXEV import sspFileName
sspFileName()
# Out:
# GridspecLayout(children=(HTML(value='<span style="color:blue">Use the dropdown menus to obtain the file name c…
# Output()

# %%
from bcplot.bcplot import pyGALAXEVcl
pyGALAXEVcl(fw)
# Out:
# Galaxy Spectral Evolution Library - pyGALAXEV
# Python Version (C) 2020-2023 - G. Bruzual and S. Charlot - All Rights Reserved
# Last revision: Sun Sep 17 2023
#
# To access a CB/BC model you may enter the full file name, e.g.:
#    0: cb2019_z0000_chab_hr_xmilesi_ssp.fits           8: cb2019_z008_chab_hr_xmilesi_ssp.fits
#    1: cb2019_z0001_chab_hr_xmilesi_ssp.fits           9: cb2019_z010_chab_hr_xmilesi_ssp.fits
#    2: cb2019_z0002_chab_hr_xmilesi_ssp.fits           a: cb2019_z014_chab_hr_xmilesi_ssp.fits
#    3: cb2019_z0005_chab_hr_xmilesi_ssp.fits           b: cb2019_z017_chab_hr_xmilesi_ssp.fits
#    4: cb2019_z001_chab_hr_xmilesi_ssp.fits            c: cb2019_z020_chab_hr_xmilesi_ssp.fits
#    5: cb2019_z002_chab_hr_xmilesi_ssp.fits            d: cb2019_z030_chab_hr_xmilesi_ssp.fits
#    6: cb2019_z004_chab_hr_xmilesi_ssp.fits            e: cb2019_z040_chab_hr_xmilesi_ssp.fits
#    7: cb2019_z006_chab_hr_xmilesi_ssp.fits            f: cb2019_z060_chab_hr_xmilesi_ssp.fits
#
#    A: bc2003_z0001_chab_hr_xmilesi_ssp.fits           D: bc2003_z008_chab_hr_xmilesi_ssp.fits
#    B: bc2003_z0004_chab_hr_xmilesi_ssp.fits           E: bc2003_z020_chab_hr_xmilesi_ssp.fits
#    C: bc2003_z004_chab_hr_xmilesi_ssp.fits            F: bc2003_z050_chab_hr_xmilesi_ssp.fits
#
# or the corresponding zlim code, defined as follows:
#     z: = (0-f)       hexadecimal number indicated above next to the file name. No default value for z.
#     l: = (m,h,i,t,b) to select the Miles, Miles+, IndoUS, Stelib, or BaSel spectral library
#     i: = (c,k,s,v)   to select the Chabrier, Kroupa, Salpeter or Vazdekis et al. IMF
#     m: = (0,1,3,6)   to select Mup = 10, 100, 300, or 600 Mo for the CB2019 Chabrier, Kroupa and Salpeter IMF models
#        = (1,2,7)     to select the BC2003 (Padova 1994 tracks), CB2003 (Padova 2000 tracks), or CB2007 models
#        = (0:9)       to select the Vazdekis IMF slope x in the CB2019 models:
#                        x = 0.3 (0), 0.8 (1), 1 (2), 1.3 (3), 1.5 (4), 1.8 (5), 2 (6), 2.3 (7), 2.8 (8), 3.3 (9)
#
#                      You must enter your choice for z. The lim codes are optional and can be entered in any order.
#                      Default values are indicated in blue. Enter ? for examples of zlim code usage.
#  BC_GALAXEV model 1 in file name [cb2019_z017_chab_hr_xmilesi_ssp.fits]  =  z004
#  BC_GALAXEV model 2 in file name [cb2019_z004_chab_hr_xmilesi_ssp.fits]  =  z008
#     Plot: s - SEDs                             Code: 0 - csp_galaxev             Legacy: 10 - model ID
#           n - SEDs (normalized)                      1 - add_bursts                      11 - filter list
#           m - photometric magnitudes                 2 - cm_evolution                    12 -
#           c - photometric colors                     3 - zmag                            13 -
#           i - line strength indices                  4 - galaxevpl
#           p - physical properties                    5 - rf_phot
#                                                      6 - of_phot
#           h - help                                   7 - bcfits2txt
#           l - list available models                  8 -
#           f - enter model file names                 9 -
#           q - quit
#  choice =  s
# Enter age of seds to plot, separated by space. Type ENTER to exit loop.
#     (Hint: -t will select a set of spectra not exceeding age t) =  -10
# Enter age of seds to plot, separated by space. Type ENTER to exit loop.
